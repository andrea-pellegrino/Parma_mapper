# %% [markdown]
# Importare i pacchetti python di base

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Importare i pacchetti GIS necessari per visualizzare

# %%
import geopandas as gpd

# %%
# Leggi il shapefile in un GeoDataFrame
gdf = gpd.read_file(r'Dati\Shapefiles\Sezioni_Censimento_PR_2011\Sezioni_Censimento_PR_2011.shp')

# %%
gdf.head()
# Out:
#    OBJECTID  COD_ISTAT  PRO_COM       SEZ2001   SEZ  COD_TIPO  COD_STAGNO  \
# 0        64    8034027    34027  3.402700e+11  1089         0           0
# 1        65    8034027    34027  3.402700e+11  1015         0           0
# 2        66    8034027    34027  3.402700e+11   343         0           0
# 3        67    8034027    34027  3.402700e+11   759         0           0
# 4        68    8034027    34027  3.402700e+11   904         0           0
#
#    COD_FIUME  COD_LAGO  COD_LAGUNA  ...  TIPO_LOC       SEZ2011  TIPO_LOC_N  \
# 0          0         0           0  ...         1  3.402700e+11           1
# 1          0         0           0  ...         1  3.402700e+11           1
# 2          0         0           0  ...         1  3.402700e+11           1
# 3          0         0           0  ...         1  3.402700e+11           1
# 4          0         0           0  ...         1  3.402700e+11           1
#
# ...

# %%
# Visualizza una mappa
gdf.plot()
# Out:
# <Axes: >
